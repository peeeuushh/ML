# %%
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
xyz_df=pd.read_csv(r"C:\Users\10726055\Downloads\XYZ_sales_data.csv")
label_encoder = preprocessing.LabelEncoder()

# %%
xyz_df['Product_Category'].dropna
xyz_df['Column']=label_encoder.fit_transform(xyz_df['Product_Category'])
xyz_df['Column']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 113031    2
# 113032    2
# 113033    2
# 113034    2
# 113035    2
# Name: Column, Length: 113036, dtype: int32

# %%
xyz_df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       26-11-2013   26  November  2013            19     Youth (<25)
# 1       26-11-2015   26  November  2015            19     Youth (<25)
# 2       23-03-2014   23     March  2014            49  Adults (35-64)
# 3       23-03-2016   23     March  2016            49  Adults (35-64)
# 4       15-05-2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  12-04-2016   12     April  2016            41  Adults (35-64)
# 113032  02-04-2014    2     April  2014            18     Youth (<25)
# 113033  02-04-2016    2     April  2016            18     Youth (<25)
# 113034  04-03-2014    4     March  2014            37  Adults (35-64)
# 113035  04-03-2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
enc =pd.get_dummies(xyz_df['Product_Category'])
enc.index = xyz_df['Date']

# %%
enc
# Out:
#             Accessories  Bikes  Clothing
# Date
# 26-11-2013         True  False     False
# 26-11-2015         True  False     False
# 23-03-2014         True  False     False
# 23-03-2016         True  False     False
# 15-05-2014         True  False     False
# ...                 ...    ...       ...
# 12-04-2016        False  False      True
# 02-04-2014        False  False      True
# 02-04-2016        False  False      True
# 04-03-2014        False  False      True
# 04-03-2016        False  False      True
#
# [113036 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df=pd.read_csv(r"C:\Users\10726055\Downloads\QWE_sales_data.csv")
vectorizer=TfidfVectorizer(ngram_range=(3,4))
X=vectorizer.fit_transform(df['review_content'])
vectorizer.get_feature_names_out()
#X.shape
#print(X)
# Out:
# array(['00 199 00', '00 199 00 999', '00 899 00', ..., '𝟱i am sorry to',
#        '𝟱you will get', '𝟱you will get webcams'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\Users\10726055\Downloads\QWE_sales_data.csv")

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
xyz_df=pd.read_csv(r"C:\Users\10726055\Downloads\XYZ_sales_data.csv")

# %%
xyz_df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       26-11-2013   26  November  2013            19     Youth (<25)
# 1       26-11-2015   26  November  2015            19     Youth (<25)
# 2       23-03-2014   23     March  2014            49  Adults (35-64)
# 3       23-03-2016   23     March  2016            49  Adults (35-64)
# 4       15-05-2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  12-04-2016   12     April  2016            41  Adults (35-64)
# 113032  02-04-2014    2     April  2014            18     Youth (<25)
# 113033  02-04-2016    2     April  2016            18     Youth (<25)
# 113034  04-03-2014    4     March  2014            37  Adults (35-64)
# 113035  04-03-2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
x=xyz_df['Product_Category']
y=xyz_df['Customer_Gender']

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=104,test_size=0.30,shuffle=True)

# %%
print('x_train:')
print(x_train.head(),x_test.head(),y_train.head(),y_test.head())
print()
# Out:
# x_train:
# 13951    Accessories
# 41313    Accessories
# 75239    Accessories
# 83133    Accessories
# 34300    Accessories
# Name: Product_Category, dtype: object 86625    Accessories
# 2644     Accessories
# 21286    Accessories
# 92375    Accessories
# 64115          Bikes
# Name: Product_Category, dtype: object 13951    F
# 41313    F
# 75239    F
# 83133    M
# 34300    F
# Name: Customer_Gender, dtype: object 86625    F
# 2644     F
# 21286    F
# 92375    M
# 64115    F
# Name: Customer_Gender, dtype: object

# %%
xyz_df['PC']=label_encoder.fit_transform(xyz_df['Product_Category'])
xyz_df['CG']=label_encoder.fit_transform(xyz_df['Customer_Gender'])

# %%
xyz_df['PC'].unique()
# Out:
# array([0, 2, 1])

# %%
sns.countplot(x=xyz_df['PC'])
plt.title('Various product categories in the dataset')
plt.show()

# %%
sns.countplot(x=xyz_df['CG'])
plt.title('Various genders in the dataset')
plt.show()

# %%
x=xyz_df[['PC']]
y=xyz_df['CG']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.30,shuffle=True)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf=RandomForestClassifier(random_state=42,n_estimators=100)
classifier_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=classifier_rf.predict(x_test)
y_pred
label_encoder.inverse_transform(y_pred)
label_encoder.classes_
# Out:
# array(['F', 'M'], dtype=object)

# %%
test = [{"PC":"Accessories"}]
df_new = pd.DataFrame(test)
df_new["PC"]= label_encoder.fit_transform(df_new)
# Out:
# C:\Users\10726055\AppData\Local\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred= classifier_rf.predict(df_new[['PC']])
y_pred
# Out:
# array([1])

# %%
label_encoder.inverse_transform(df_new)
# Out:
# C:\Users\10726055\AppData\Local\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array(['Accessories'], dtype=object)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy=accuracy_score(y_test,x_test)
c_matrix=classification_report(y_test,x_test)
print("Accuracy:{:.2f}%".format(accuracy*100))
# Out:
# Accuracy:41.72%
# C:\Users\10726055\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\10726055\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\10726055\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print(c_matrix)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.62      0.54     16417
#            1       0.51      0.23      0.31     17494
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.42     33911
#    macro avg       0.33      0.28      0.29     33911
# weighted avg       0.50      0.42      0.43     33911

# %%
xyz_df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       26-11-2013   26  November  2013            19     Youth (<25)
# 1       26-11-2015   26  November  2015            19     Youth (<25)
# 2       23-03-2014   23     March  2014            49  Adults (35-64)
# 3       23-03-2016   23     March  2016            49  Adults (35-64)
# 4       15-05-2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  12-04-2016   12     April  2016            41  Adults (35-64)
# 113032  02-04-2014    2     April  2014            18     Youth (<25)
# 113033  02-04-2016    2     April  2016            18     Youth (<25)
# 113034  04-03-2014    4     March  2014            37  Adults (35-64)
# 113035  04-03-2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
xyz_df['CG']=label_encoder.fit_transform(xyz_df['Customer_Gender'])
xyz_df['CA']=label_encoder.fit_transform(xyz_df['Customer_Age'])

xyz_df['PC']=label_encoder.fit_transform(xyz_df['Product_Category'])

# %%
X=xyz_df[['CA','CG']]

Y=xyz_df['PC']

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=42,test_size=0.30,shuffle=True)

# %%
classifier_rf=RandomForestClassifier(random_state=42,n_estimators=100)
classifier_rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
Y_pred=classifier_rf.predict(X_test)
Y_pred
label_encoder.inverse_transform(Y_pred)
label_encoder.classes_
# Out:
# array(['Accessories', 'Bikes', 'Clothing'], dtype=object)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy=accuracy_score(Y_test,Y_pred)
c_matrix=classification_report(Y_test,Y_pred)
print("Accuracy:{:.2f}%".format(accuracy*100))
# Out:
# Accuracy:61.87%
# C:\Users\10726055\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\10726055\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\10726055\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
