# %%
import pandas as pd
import numpy as np

# %%
sales_df=pd.read_csv(r'C:\Users\10726055\Downloads\sales_data (2).csv')

# %%
sales_df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales_df.dtypes
# Out:
# Date                object
# Day                  int64
# Month               object
# Year                 int64
# Customer_Age         int64
# Age_Group           object
# Customer_Gender     object
# Country             object
# State               object
# Product_Category    object
# Sub_Category        object
# Product             object
# Order_Quantity       int64
# Unit_Cost            int64
# Unit_Price           int64
# Profit               int64
# Cost                 int64
# Revenue              int64
# dtype: object

# %%
type(sales_df['Customer_Age'])
# Out:
# pandas.core.series.Series

# %%
type(sales_df[['Customer_Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
sales_df.loc[1:3]
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
#
#    Revenue
# 1      950
# 2     2401
# 3     2088

# %%
sales_df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
sales_df[sales_df['Month']=='November']
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0       2013-11-26   26  November  2013            19           Youth (<25)
# 1       2015-11-26   26  November  2015            19           Youth (<25)
# 36      2013-11-11   11  November  2013            34  Young Adults (25-34)
# 37      2015-11-11   11  November  2015            34  Young Adults (25-34)
# 46      2013-11-17   17  November  2013            29  Young Adults (25-34)
# ...            ...  ...       ...   ...           ...                   ...
# 112923  2015-11-07    7  November  2015            39        Adults (35-64)
# 112938  2013-11-16   16  November  2013            79         Seniors (64+)
# 112939  2015-11-16   16  November  2015            79         Seniors (64+)
# 112950  2013-11-01    1  November  2013            35        Adults (35-64)
# 112951  2015-11-01    1  November  2015            35        Adults (35-64)
#
# ...

# %%
sales_df[(sales_df['Month']=='November')&(sales_df['Customer_Age']==34)&(sales_df['State']=='Queensland')]
# Out:
#              Date  Day     Month  Year  Customer_Age             Age_Group  \
# 868    2013-11-10   10  November  2013            34  Young Adults (25-34)
# 869    2015-11-10   10  November  2015            34  Young Adults (25-34)
# 16806  2013-11-04    4  November  2013            34  Young Adults (25-34)
# 16807  2013-11-04    4  November  2013            34  Young Adults (25-34)
# 16808  2015-11-04    4  November  2015            34  Young Adults (25-34)
# 16809  2015-11-04    4  November  2015            34  Young Adults (25-34)
# 21782  2013-11-25   25  November  2013            34  Young Adults (25-34)
# 21783  2015-11-25   25  November  2015            34  Young Adults (25-34)
# 22366  2013-11-24   24  November  2013            34  Young Adults (25-34)
# 22367  2015-11-24   24  November  2015            34  Young Adults (25-34)
# 36278  2013-11-04    4  November  2013            34  Young Adults (25-34)
# ...

# %%
sales_df[['Month','State','Country']]
# Out:
#            Month             State         Country
# 0       November  British Columbia          Canada
# 1       November  British Columbia          Canada
# 2          March   New South Wales       Australia
# 3          March   New South Wales       Australia
# 4            May   New South Wales       Australia
# ...          ...               ...             ...
# 113031     April           England  United Kingdom
# 113032     April        Queensland       Australia
# 113033     April        Queensland       Australia
# 113034     March     Seine (Paris)          France
# 113035     March     Seine (Paris)          France
#
# [113036 rows x 3 columns]

# %%
pd.DataFrame(pd.Series(sales_df['Product'].unique()))
# Out:
#                           0
# 0       Hitch Rack - 4-Bike
# 1    All-Purpose Bike Stand
# 2      Mountain Bottle Cage
# 3     Water Bottle - 30 oz.
# 4          Road Bottle Cage
# ..                      ...
# 125   Touring-2000 Blue, 50
# 126   Touring-2000 Blue, 60
# 127         Classic Vest, L
# 128         Classic Vest, M
# 129         Classic Vest, S
#
# [130 rows x 1 columns]

# %%
sales_df['Product']
# Out:
# 0         Hitch Rack - 4-Bike
# 1         Hitch Rack - 4-Bike
# 2         Hitch Rack - 4-Bike
# 3         Hitch Rack - 4-Bike
# 4         Hitch Rack - 4-Bike
#                  ...
# 113031        Classic Vest, S
# 113032        Classic Vest, M
# 113033        Classic Vest, M
# 113034        Classic Vest, L
# 113035        Classic Vest, L
# Name: Product, Length: 113036, dtype: object

# %%
sales_df['Product']
# Out:
# 0         Hitch Rack - 4-Bike
# 1         Hitch Rack - 4-Bike
# 2         Hitch Rack - 4-Bike
# 3         Hitch Rack - 4-Bike
# 4         Hitch Rack - 4-Bike
#                  ...
# 113031        Classic Vest, S
# 113032        Classic Vest, M
# 113033        Classic Vest, M
# 113034        Classic Vest, L
# 113035        Classic Vest, L
# Name: Product, Length: 113036, dtype: object

# %%
profit_df=df[['Profit','Product']]

# %%
grouped_profit_df=profit_df.groupby('Product').sum()

# %%
grouped_profit_df['Profit']
# Out:
# Product
# AWC Logo Cap                   78008
# All-Purpose Bike Stand        201064
# Bike Wash - Dissolver         116008
# Classic Vest, L               157319
# Classic Vest, M               161740
#                                ...
# Touring-3000 Yellow, 62        18371
# Water Bottle - 30 oz.         417843
# Women's Mountain Shorts, L    286059
# Women's Mountain Shorts, M    394913
# Women's Mountain Shorts, S    355189
# Name: Profit, Length: 130, dtype: int64

# %%
profitc_df=df[['Profit','Product_Category']]

# %%
grouped_profitc_df=profitc_df.groupby('Product_Category').sum()

# %%
profitc_df.groupby('Product_Category').sum()
# Out:
#                     Profit
# Product_Category
# Accessories        8862377
# Bikes             20519276
# Clothing           2839447

# %%
sales_df[(sales_df['Year']==2013)&(sales_df['Product_Category']=='Accessories')]['Profit'].sum()
# Out:
# 1985231

# %%
sales_df[['Age_Group','Product']][(sales_df['Year']==2015)].groupby('Age_Group').count()
# Out:
#                       Product
# Age_Group
# Adults (35-64)          11236
# Seniors (64+)             131
# Young Adults (25-34)     8785
# Youth (<25)              4291

# %%
sales_df.at[4,'Date']
# Out:
# '2014-05-15'

# %%
type(sales_df.at[0,'Date'])
# Out:
# str

# %%
sales_df['Date']
# Out:
# 0         2013-11-26
# 1         2015-11-26
# 2         2014-03-23
# 3         2016-03-23
# 4         2014-05-15
#              ...
# 113031    2016-04-12
# 113032    2014-04-02
# 113033    2016-04-02
# 113034    2014-03-04
# 113035    2016-03-04
# Name: Date, Length: 113036, dtype: object

# %%
from datetime import timedelta
sales_df['Date']=pd.to_datetime(sales_df['Date'])

# %%
sales_df['Date']=sales_df['Date']+timedelta(hours=24)

# %%
sales_df['Date']
# Out:
# 0        2013-11-29
# 1        2015-11-29
# 2        2014-03-26
# 3        2016-03-26
# 4        2014-05-18
#             ...
# 113031   2016-04-15
# 113032   2014-04-05
# 113033   2016-04-05
# 113034   2014-03-07
# 113035   2016-03-07
# Name: Date, Length: 113036, dtype: datetime64[ns]

# %%
df['New_Column']=df['Product_Category']+" / "+df['Sub_Category']

# %%
df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
sales_df[(sales_df['Year']==2015)].groupby('Age_Group')['Profit'].sum()
# Out:
# Age_Group
# Adults (35-64)          3436847
# Seniors (64+)             19994
# Young Adults (25-34)    2880608
# Youth (<25)             1191114
# Name: Profit, dtype: int64

# %%
sales_df[(sales_df['Year']==2015)&(sales_df['Age_Group']=='Adults (35-64)')].groupby('Sub_Category')['Product'].count()
# Out:
# Sub_Category
# Bike Racks             63
# Bike Stands            53
# Bottles and Cages    1575
# Caps                  392
# Cleaners              204
# Fenders               426
# Gloves                279
# Helmets              1235
# Hydration Packs       145
# Jerseys               573
# Mountain Bikes        925
# Road Bikes           1216
# Shorts                192
# Socks                 107
# Tires and Tubes      3399
# Touring Bikes         358
# Vests                  94
# Name: Product, dtype: int64

# %%
from sklearn import preprocessing
