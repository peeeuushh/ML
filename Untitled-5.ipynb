# %%
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
label_encoder = preprocessing.LabelEncoder()

# %%
df=pd.read_csv(r"C:\Users\10726055\Downloads\alerts-data.csv")
df=df.dropna
df

vectorizer=TfidfVectorizer(ngram_range=(3,3))
X=vectorizer.fit_transform(df["description"])
Y=label_encoder.fit_transform(df['kpi'])
Y=df['KPI']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=42,test_size=0.30,shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-5.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:Untitled-5.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=0'>1</a> df=pd.read_csv(r"C:\Users\10726055\Downloads\alerts-data.csv")
#       <a href='vscode-notebook-cell:Untitled-5.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=1'>2</a> df=df.dropna
#       <a href='vscode-notebook-cell:Untitled-5.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=2'>3</a> df
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#                      ciImpacted  \
# 0          M1SCCMHV02.mmi.local
# 1        0004svr.banfield.local
# 2     CTS-DEVSQA-RTR2.mmi.local
# 3        0919SVR.banfield.local
# 4           DEV04BIZ1.mmi.local
# ...                         ...
# 9683                    0220-64
# 9684                  2161-MR33
# 9685                    1508-64
# 9686                  1063-MR42
# 9687                  1063-MR33
#
#                                             description  \
# 0     Cluster node M1SCCMHV02.mmi.local in cluster M...
# 1     The System Center Management Health Service on...
# 2     Alert will be triggered if any CTS DC node wil...
# 3     The Windows Storport Miniport Driver has timed...
# 4     The System Center Management Health Service on...
# ...                                                 ...
# 9683  This alert will write to the SolarWinds event ...
# 9684                                      APs went down
# 9685                        Client IP conflict detected
# 9686                                      APs went down
# 9687                                      APs went down
#
#                               kpi  lastModifiedTime  status    alertId
# 0       Cluster Node Availability  21-01-2023 09:29  Active   97242184
# 1        Heartbeat Status Windows  23-01-2023 06:54  Active   87803708
# 2                   CTS Node Down  23-01-2023 11:31  Active   87807873
# 3                Request Time Out  24-01-2023 20:14  Active   87822509
# 4        Heartbeat Status Windows  31-01-2023 05:19  Active  103324401
# ...                           ...               ...     ...        ...
# 9683           High Response Time  25-08-2023 04:17  Active  165148194
# 9684         Access Points Status  25-08-2023 03:37  Active  707407898
# 9685  Client IP Conflict Detected  25-08-2023 05:02  Active  769298615
# 9686         Access Points Status  25-08-2023 04:51  Active  769299197
# 9687         Access Points Status  25-08-2023 04:52  Active  771268994
#
# [9688 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-5.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:Untitled-5.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=0'>1</a> vectorizer=TfidfVectorizer(ngram_range=(3,3))
# ----> <a href='vscode-notebook-cell:Untitled-5.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=1'>2</a> x=vectorizer.fit_transform(df['description'])
#       <a href='vscode-notebook-cell:Untitled-5.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=2'>3</a> df['kpi']=label_encoder.fit_transform(df['kpi'])
#       <a href='vscode-notebook-cell:Untitled-5.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=3'>4</a> y=df['kpi']
#
# TypeError: 'method' object is not subscriptable
